# %%
import random
choices=["Rock","Paper","Scissors"]


computer_score=0
winner_score=0



player=False 

computer=random.choice(choices)
while True:
    player = input("Rock, Paper or  Scissors?").capitalize()
    if (player == "Scissors" and computer == "Paper"):
        winner_score+=1
        print("Player wins")
        print(winner_score)
        print(computer_score)
        
    elif (player == "Paper" and computer == "Scissors"):
        computer_score+=1
        print("Computer wins")
        print(winner_score)
        print(computer_score)
        
        
    elif (player == "Rock" and computer == "Scissors"):
        winner_score+=1
        print("Player wins")
        print(winner_score)
        print(computer_score)
        
    elif (player == "Scissors" and computer == "Rock"):
        computer_score+=1
        print("Computer wins")
        print(winner_score)
        print(computer_score)
        
        
    elif (player == "Rock" and computer == "Paper"):
        winner_score+=1 
        print("Player wins")
        print(winner_score)
        print(computer_score)
         
    elif (player == "Paper" and computer == "Rock"):
        computer_score+=1
        print("Computer wins")
        print(winner_score)
        print(computer_score)
        
    
   
    elif (player == "Scissors" and computer == "Scissors"):
        print("Nobody wins")
        print(winner_score)
        print(computer_score)
    elif (player == "Rock" and computer == "Rock"):
        print("Nobody wins")
        print(winner_score)
        print(computer_score)
    elif (player == "Paper" and computer =="Paper"):
        print("Nobody wins")
        print(winner_score)
        print(computer_score)
        
    if (player == "End"):
        if (winner_score > computer_score):
            print("Player wins the full game")
        elif(winner_score == computer_score):
            print("Nobody wins")
        else:
            print("Computer wins the game")
# Out:
# Rock, Paper or  Scissors?rock
# Player wins
# 1
# 0
# Rock, Paper or  Scissors?scissors
# Nobody wins
# 1
# 0
# Rock, Paper or  Scissors?paper
# Computer wins
# 1
# 1
