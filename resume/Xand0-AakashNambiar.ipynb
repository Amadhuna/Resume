# %%
from tkinter import *
from tkinter import messagebox

# %%
window=Tk()
window.title('Tic-Tac-toe')
window.geometry("400x400")
window.configure(bg="light blue")



a = TRUE  
def button_click(Buttons):
    global a
    if Buttons['text']=='':
        if (a):
            a = FALSE
            Buttons['text'] = 'X'
        else:
            a= TRUE
            Buttons['text'] = 'O'
    winner()
            
        
def button_clear():
    btn1['text']=''
    btn1.configure(bg="light green")
    btn2['text']=''
    btn2.configure(bg="light green")
    btn3['text']=''
    btn3.configure(bg="light green")
    btn4['text']=''
    btn4.configure(bg="light green")
    btn5['text']=''
    btn5.configure(bg="light green")
    btn6['text']=''
    btn6.configure(bg="light green")
    btn7['text']=''
    btn7.configure(bg="light green")
    btn8['text']=''
    btn8.configure(bg="light green")
    btn9['text']=''
    btn9.configure(bg="light green")

    
def winner():
    if (btn1['text'] == 'X' and btn2['text'] == 'X' and btn3['text'] == 'X'):
        btn1.configure(bg="RED")
        btn2.configure(bg="RED")
        btn3.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 1 is Winner')
    elif (btn1['text'] == 'O' and btn2['text'] == 'O' and btn3['text'] == 'O'):
        btn1.configure(bg="RED")
        btn2.configure(bg="RED")
        btn3.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 2 is Winner')
        
    elif (btn1['text'] == 'O' and btn4['text'] == 'O' and btn7['text'] == 'O'):
        btn1.configure(bg="RED")
        btn4.configure(bg="RED")
        btn7.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 2 is Winner')
    elif (btn1['text'] == 'X' and btn4['text'] == 'X' and btn7['text'] == 'X'):
        btn1.configure(bg="RED")
        btn4.configure(bg="RED")
        btn7.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 1 is Winner')
        
    elif (btn7['text'] == 'O' and btn8['text'] == 'O' and btn9['text'] == 'O'):
        btn7.configure(bg="RED")
        btn8.configure(bg="RED")
        btn9.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 2 is Winner')
    elif (btn7['text'] == 'X' and btn8['text'] == 'X' and btn9['text'] == 'X'):
        btn7.configure(bg="RED")
        btn8.configure(bg="RED")
        btn9.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 1 is Winner')
        
    elif (btn3['text'] == 'X' and btn6['text'] == 'X' and btn9['text'] == 'X'):
        btn3.configure(bg="RED")
        btn6.configure(bg="RED")
        btn9.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 1 is Winner')
    elif (btn3['text'] == 'O' and btn6['text'] == 'O' and btn9['text'] == 'O'):
        btn3.configure(bg="RED")
        btn6.configure(bg="RED")
        btn9.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 2 is Winner')
        
    elif (btn4['text'] == 'X' and btn5['text'] == 'X' and btn6['text'] == 'X'):
        btn4.configure(bg="RED")
        btn5.configure(bg="RED")
        btn6.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 1 is Winner')
    elif (btn4['text'] == 'O' and btn5['text'] == 'O' and btn6['text'] == 'O'):
        btn4.configure(bg="RED")
        btn5.configure(bg="RED")
        btn6.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 2 is Winner')
        
    elif (btn1['text'] == 'X' and btn5['text'] == 'X' and btn9['text'] == 'X'):
        btn1.configure(bg="RED")
        btn5.configure(bg="RED")
        btn9.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 1 is Winner')
    elif (btn1['text'] == 'O' and btn5['text'] == 'O' and btn9['text'] == 'O'):
        btn1.configure(bg="RED")
        btn5.configure(bg="RED")
        btn9.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 2 is Winner')
        
    elif (btn3['text'] == 'X' and btn5['text'] == 'X' and btn7['text'] == 'X'):
        btn3.configure(bg="RED")
        btn5.configure(bg="RED")
        btn7.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 1 is Winner')
    elif (btn3['text'] == 'O' and btn5['text'] == 'O' and btn7['text'] == 'O'):
        btn3.configure(bg="RED")
        btn5.configure(bg="RED")
        btn7.configure(bg="RED")
        res=messagebox.showinfo("Information",'Player 2 is Winner')
    elif (btn1['text'] != '' and btn2['text'] != '' and btn3['text'] != ''
         and btn4['text'] != '' and btn5['text'] != '' and btn6['text'] != ''
         and btn7['text'] != '' and btn8['text'] != '' and btn9['text'] != ''):
        res=messagebox.showinfo("Information",'No Winner')
        
        return res
    
    
mainframe=Frame(window,height=200,width=400)
mainframe.place(x=0,y=0)

btn1=Button(mainframe,text="",height=5,width=10,bd=5,bg="light green",command=lambda: button_click(btn1))
btn1.grid(row=0,column=0)

btn2=Button(mainframe,text="",height=5,width=10,bd=5,bg="light green",command=lambda: button_click(btn2))
btn2.grid(row=0,column=1)

btn3=Button(mainframe,text="",height=5,width=10,bd=5,bg="light green",command=lambda: button_click(btn3))
btn3.grid(row=0,column=2)

btn4=Button(mainframe,text="",height=5,width=10,bd=5,bg="light green",command=lambda: button_click(btn4))
btn4.grid(row=1,column=0)

btn5=Button(mainframe,text="",height=5,width=10,bd=5,bg="light green",command=lambda: button_click(btn5))
btn5.grid(row=1,column=1)

btn6=Button(mainframe,text="",height=5,width=10,bd=5,bg="light green",command=lambda: button_click(btn6))
btn6.grid(row=1,column=2)

btn7=Button(mainframe,text="",height=5,width=10,bd=5,bg="light green",command=lambda: button_click(btn7))
btn7.grid(row=2,column=0)

btn8=Button(mainframe,text="",height=5,width=10,bd=5,bg="light green",command=lambda: button_click(btn8))
btn8.grid(row=2,column=1)

btn9=Button(mainframe,text="",height=5,width=10,bd=5,bg="light green",command=lambda: button_click(btn9))
btn9.grid(row=2,column=2)

reset_button= Button(text="Start Again",font="ariel",command=lambda:button_clear())
reset_button.place(x=150,y=350)

window.mainloop()
